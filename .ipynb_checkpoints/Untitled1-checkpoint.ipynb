# %%
import numpy as np
# %matplotlib inline
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
x = np.array([(62,397,103),
                        (82,347,107),
                        (93,288,120),
                        (94,266,128),
                        (65,163,169),
                        (12,102,198),
                        (48,138,180),
                        (77,187,157),
                        (85,209,149),
                        (89,316,112)])
print(x[:, 0])
print(x[:, 1])
print(x[:, 2])
# Out:
# [62 82 93 94 65 12 48 77 85 89]
# [397 347 288 266 163 102 138 187 209 316]
# [103 107 120 128 169 198 180 157 149 112]

# %%
X = x[:, 0]
Y = x[:, 1]
Z = x[:, 2]

fig = plt.figure()
ax = Axes3D(fig)
Axes3D.scatter(X, Y, Z, zdir='z', s=20, c=None, depthshade=True)
#ax.plot_wireframe(X,Y,Z)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e07f4339c37b> in <module>
#       5 fig = plt.figure()
#       6 ax = Axes3D(fig)
# ----> 7 Axes3D.scatter(X, Y, Z, zdir='z', s=20, c=None, depthshade=True, *args, **kwarg)
#       8 #ax.plot_wireframe(X,Y,Z)
#       9 plt.show()
#
# NameError: name 'args' is not defined

# %%
xm = np.mean(x,axis=0)
x = x - xm
print(xm.shape)
print(x.shape)
# Out:
# (3,)
# (10, 3)

# %%
v, s, t = np.linalg.svd(x,full_matrices=True)

# %%
sigma1 = s[0]
sigma2 = s[1]
sigma3 = s[2]
v1 = t[0]
v2 = t[1]
v3 = t[2]

# %%
Z = np.zeros((x.shape[0],10), np.float32)
Z[:,0] = x[:,0]**2
Z[:,1] = 2*x[:,0]*x[:,1]
Z[:,2] = 2*x[:,0]*x[:,2]
Z[:,3] = 2*x[:,0]
Z[:,4] = x[:,1]**2
Z[:,5] = 2*x[:,1]*x[:,2]
Z[:,6] = 2*x[:,1]
Z[:,7] = x[:,2]**2
Z[:,8] = 2*x[:,2]
Z[:,9] = 1
print(Z)
# Out:
# [[ 7.569000e+01 -2.709180e+03  6.838200e+02 -1.740000e+01  2.424249e+04
#   -1.223802e+04  3.114000e+02  1.544490e+03 -7.860000e+01  1.000000e+00]
#  [ 1.276900e+02  2.388820e+03 -7.977800e+02  2.260000e+01  1.117249e+04
#   -7.462420e+03  2.114000e+02  1.246090e+03 -7.060000e+01  1.000000e+00]
#  [ 4.972900e+02  2.082820e+03 -9.945800e+02  4.460000e+01  2.180890e+03
#   -2.082820e+03  9.340000e+01  4.972900e+02 -4.460000e+01  1.000000e+00]
#  [ 5.428900e+02  1.151020e+03 -6.663800e+02  4.660000e+01  6.100900e+02
#   -7.064200e+02  4.940000e+01  2.044900e+02 -2.860000e+01  1.000000e+00]
#  [ 3.249000e+01  8.926200e+02 -3.043800e+02 -1.140000e+01  6.130890e+03
#   -4.181220e+03 -1.566000e+02  7.128900e+02  5.340000e+01  1.000000e+00]
#  [ 3.445690e+03  1.635382e+04 -6.539180e+03 -1.174000e+02  1.940449e+04
#   -1.551802e+04 -2.786000e+02  3.102490e+03  1.114000e+02  1.000000e+00]
#  [ 5.152900e+02  4.689820e+03 -1.711580e+03 -4.540000e+01  1.067089e+04
#   -7.788820e+03 -2.066000e+02  1.421290e+03  7.540000e+01  1.000000e+00]
#  [ 3.969000e+01 -6.841800e+02  1.852200e+02  1.260000e+01  2.948490e+03
#   -1.596420e+03 -1.086000e+02  2.160900e+02  2.940000e+01  1.000000e+00]
#  [ 2.044900e+02 -9.237800e+02  1.916200e+02  2.860000e+01  1.043290e+03
#   -4.328200e+02 -6.460000e+01  4.489000e+01  1.340000e+01  1.000000e+00]
#  [ 3.348900e+02  2.734020e+03 -1.108980e+03  3.660000e+01  5.580090e+03
#   -4.526820e+03  1.494000e+02  9.180900e+02 -6.060000e+01  1.000000e+00]]

# %%
v, s, t = np.linalg.svd(Z,full_matrices=True)
smallest_value = np.min(np.array(s))
smallest_index = np.argmin(np.array(s))
T = np.array(t)
T = T[smallest_index,:]
S = np.zeros((4,4),np.float32)
S[0,0] = T[0]
S[0,1] = S[1,0] = T[1]
S[0,2] = S[2,0] = T[2]
S[0,3] = S[3,0] = T[3]
S[1,1] = T[4]
S[1,2] = S[2,1] = T[5]
S[1,3] = S[3,1] = T[6]
S[2,2] = T[7]
S[2,3] = S[3,2] = T[8]
S[3,3] = T[9]
norm = np.linalg.norm(np.dot(Z,T), ord=2)**2
print(norm)
# Out:
# 8.881784197001252e-14

# %%
print(S)
# Out:
# [[-1.1228298e-04  2.8074703e-05  2.8081497e-05 -2.0666152e-02]
#  [ 2.8074703e-05 -7.0175709e-05  5.6151704e-05  5.1665432e-03]
#  [ 2.8081497e-05  5.6151704e-05 -7.0150170e-05  5.1665511e-03]
#  [-2.0666152e-02  5.1665432e-03  5.1665511e-03  9.9975973e-01]]
